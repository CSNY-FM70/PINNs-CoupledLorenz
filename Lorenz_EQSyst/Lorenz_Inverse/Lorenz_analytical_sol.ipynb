# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
rho = 15
sigma = 10
beta = 8/3

# %%
def f(state, t):
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

# %%
state0 = [7, 15, 15]
time = np.arange(0.0, 5.0, 0.01)
timedata = np.arange(0.0, 5.0, 0.01)[:,np.newaxis]

# %%
states = odeint(f, state0, time)

# %%
np.savez ('/home/Alejandro/Gitlab/pinns/Lorenz_EQSyst/data', t=timedata, w=states)
data = np.load('/home/Alejandro/Gitlab/pinns/Lorenz_EQSyst/data.npz')
#print(data['t'])
#print(data['w'])
print (len (data['t']))
print (len (data['w']))
# Out:
# 500
# 500

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.draw()
plt.show()
# Out:
# /tmp/ipykernel_22039/2774728347.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")
